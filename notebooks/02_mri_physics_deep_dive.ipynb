# %% [markdown]
# # MRI physics deep dive
# Use this notebook to explore the documented signal model without changing production preprocessing.

# %%
from orion.data.mri.physics import bloch_equation_signal
bloch_equation_signal(PD=1.0, T1=900, T2=50, TR=2000, TE=30)
