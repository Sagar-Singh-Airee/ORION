# %% [markdown]
# # DICOM EDA
# Inspect only de-identified metadata, sequence counts, dimensions, and missing fields before training.

# %%
# See scripts/eda.py and scripts/preprocess.py for the reproducible pipeline.
