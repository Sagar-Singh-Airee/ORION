# %% [markdown]
# # Weak-label analysis
# Inspect evidence and abstentions. Never convert an absent mention into a negative label.

# %%
# python scripts/extract_weak_labels.py --reports-csv <reports.csv> --output <weak.csv> --evidence-output <evidence.jsonl>
