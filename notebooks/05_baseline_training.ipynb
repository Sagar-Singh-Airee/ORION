# %% [markdown]
# # Baseline training
# Run this workflow in Kaggle only, after creating immutable patient-safe folds.

# %%
# python scripts/train.py --config configs/experiment/baseline_resnet50.yaml data.metadata_csv=<folds.csv> data.splits.fold=0
