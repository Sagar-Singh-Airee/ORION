# %% [markdown]
# # Multimodal experiments
# Enable report fusion only after image-only OOF validation is stable.

# %%
# Set data.multimodal=true and model.text_encoder.enabled=true in an experiment override.
